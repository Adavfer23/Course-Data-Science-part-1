# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ana**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it is amazing how much you can find out by working with data*

# %% [markdown]
# ### I am going to show you a simple code, like a sum

# %%
1+1
# Out:
# 2

# %% [markdown]
# | Country     | Continent |
# |   -------   | ----      |
# | 1.France | -Europe   |
# |  2.Japan    | -Asia     |
# | 3.Tunisia   | -Africa   |
# | 4.Panama    | -America  |
# | 5.Australia | -Oceania  |
#
# ***
# > If you need more information about Jupyter Notebook
# >
# > [For more information about Jupyter Notebook](https://nbviewer.org/github/ipython/ipython/blob/3.x/examples/Notebook/Index.ipynb)
